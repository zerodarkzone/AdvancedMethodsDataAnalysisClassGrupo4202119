# %% [markdown]
# # Exercise 03 - Autoregressive Integrated Moving Average Models
#
# - The result will be evaluated from a report in Jupyter, which must be found in a public GitHub repository.
# - The project must be carried out in the groups assigned in class.
# - Use clear and rigorous procedures.
# - Due date: July 11, 2021, 11:59 pm, through Bloque Neón + (Upload repository link)
#
# # 03.1 - Plot and analyze the ACF and PACF of the 4 time series in data_arma.csv:
#
# ### What do these plots suggest about the data being an AR or MA process?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
# %matplotlib inline
sns.set()

# %%
# Cargar dataset
data_arma_df = pd.read_csv('../datasets/data_arma.csv')
data_arma_df.head()
# Out:
#    Unnamed: 0       ts1       ts2       ts3       ts4
# 0           0  0.533570 -0.126804 -0.802837  1.812825
# 1           1  1.240130  1.314360 -0.595602  0.042764
# 2           2  1.618598  1.405994  0.127180 -1.759427
# 3           3  1.140465  3.132621  0.958586 -0.456798
# 4           4  0.481561  3.179083  0.164598 -1.254790

# %%
plot_acf( data_arma_df.ts1, lags=50);
plot_pacf( data_arma_df.ts1, lags=50);

# %%
plot_acf( data_arma_df.ts2, lags=50);
plot_pacf( data_arma_df.ts2, lags=50);

# %%
plot_acf( data_arma_df.ts3, lags=50);
plot_pacf( data_arma_df.ts3, lags=50);

# %%
plot_acf( data_arma_df.ts4, lags=50);
plot_pacf( data_arma_df.ts4, lags=50);

# %% [markdown]
# # 03.2 - Using the shampoo dataset:
#
# ### Find the parameters p, d q that minimize the mean squared error (MSE) of the rolling forecast.
